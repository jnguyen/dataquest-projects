# %% [markdown]
# # Exploring Ebay Car Sales Data
# Author: Jimmy Nguyen

# %% [markdown]
# ## Introduction
#
# In this project, I look at car sales data from *eBay Kleinanzeigen*, a classifieds section of the German eBay website.
#
# Data dictionary for the raw data provided:
#
# *  `dateCrawled` - When this ad was first crawled. All field-values are taken from this date.
# *  `name` - Name of the car.
# *  `seller` - Whether the seller is private or a dealer.
# *  `offerType` - The type of listing
# *  `price` - The price on the ad to sell the car.
# *  `abtest` - Whether the listing is included in an A/B test.
# *  `vehicleType` - The vehicle Type.
# *  `yearOfRegistration` - The year in which the car was first registered.
# *  `gearbox` - The transmission type.
# *  `powerPS` - The power of the car in PS.
# *  `model` - The car model name.
# *  `kilometer` - How many kilometers the car has driven.
# *  `monthOfRegistration` - The month in which the car was first registered.
# *  `fuelType` - What type of fuel the car uses.
# *  `brand` - The brand of the car.
# *  `notRepairedDamage` - If the car has a damage which is not yet repaired.
# *  `dateCreated` - The date on which the eBay listing was created.
# *  `nrOfPictures` - The number of pictures in the ad.
# *  `postalCode` - The postal code for the location of the vehicle.
# *  `lastSeenOnline` - When the crawler saw this ad last online.

# %%
# Import data analysis libraries
import numpy as np
import pandas as pd

# %%
# Read in eBay car sales dataset
autos = pd.read_csv("autos.csv", encoding = "Latin-1")

# %% [markdown]
# ## Examining The Data
# This dataset has 50,000 rows and 20 features. Each row is a car sale containing information about the seller and the car sold.

# %%
# Print basic information about the dataset
autos.info()
autos.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# dateCrawled            50000 non-null object
# name                   50000 non-null object
# seller                 50000 non-null object
# offerType              50000 non-null object
# price                  50000 non-null object
# abtest                 50000 non-null object
# vehicleType            44905 non-null object
# yearOfRegistration     50000 non-null int64
# gearbox                47320 non-null object
# powerPS                50000 non-null int64
# model                  47242 non-null object
# odometer               50000 non-null object
# monthOfRegistration    50000 non-null int64
# fuelType               45518 non-null object
# brand                  50000 non-null object
# notRepairedDamage      40171 non-null object
# dateCreated            50000 non-null object
# nrOfPictures           50000 non-null int64
# postalCode             50000 non-null int64
# lastSeen               50000 non-null object
# dtypes: int64(5), object(15)
# memory usage: 7.6+ MB
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType  yearOfRegistration  \
# 0  privat   Angebot  $5,000  control         bus                2004
# 1  privat   Angebot  $8,500  control   limousine                1997
# 2  privat   Angebot  $8,990     test   limousine                2009
# 3  privat   Angebot  $4,350  control  kleinwagen                2007
# 4  privat   Angebot  $1,350     test       kombi                2003
#
#      gearbox  powerPS   model   odometer  monthOfRegistration fuelType  \
# 0    manuell      158  andere  150,000km                    3      lpg
# 1  automatik      286     7er  150,000km                    6   benzin
# 2    manuell      102    golf   70,000km                    7   benzin
# 3  automatik       71  fortwo   70,000km                    6   benzin
# 4    manuell        0   focus  150,000km                    7   benzin
#
#         brand notRepairedDamage          dateCreated  nrOfPictures  \
# 0     peugeot              nein  2016-03-26 00:00:00             0
# 1         bmw              nein  2016-04-04 00:00:00             0
# 2  volkswagen              nein  2016-03-26 00:00:00             0
# 3       smart              nein  2016-03-12 00:00:00             0
# 4        ford              nein  2016-04-01 00:00:00             0
#
#    postalCode             lastSeen
# 0       79588  2016-04-06 06:45:54
# 1       71034  2016-04-06 14:45:08
# 2       35394  2016-04-06 20:15:37
# 3       33729  2016-03-15 03:16:28
# 4       39218  2016-04-01 14:38:50

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Cleaning up column names
# Let's convert the column names to Python's preferred `snake_case` and rename the columns to facilitate working with the data.
#
# We'll accomplish this by manually renaming some columns, and then using `regex` matching to insert underscores between camelCase words, and then finally making all column names lower case using `Series.str.lower()`.

# %%
# Convert column names from camelCase to snake_case
autos.columns = (autos.columns
         .str.replace('yearOfRegistration', 'registration_year')
         .str.replace('monthOfRegistration', 'registration_month')
         .str.replace('notRepairedDamage', 'unrepaired_damage')
         .str.replace('dateCreated', 'ad_created')
         .str.replace(r'([A-Z][a-z]+)', r'_\1') # insert _ between words
         .str.lower()
    )
list(autos)
# Out:
# ['date_crawled',
#  'name',
#  'seller',
#  'offer_type',
#  'price',
#  'abtest',
#  'vehicle_type',
#  'registration_year',
#  'gearbox',
#  'powerps',
#  'model',
#  'odometer',
#  'registration_month',
#  'fuel_type',
#  'brand',
#  'unrepaired_damage',
#  'ad_created',
#  'nr_of_pictures',
#  'postal_code',
#  'last_seen']

# %% [markdown]
# ### Missing Values and Outliers

# %%
# Calculate percentage of missing features
autos.isnull().sum()/autos.shape[0] * 100
# Out:
# date_crawled           0.000
# name                   0.000
# seller                 0.000
# offer_type             0.000
# price                  0.000
# abtest                 0.000
# vehicle_type          10.190
# registration_year      0.000
# gearbox                5.360
# powerps                0.000
# model                  5.516
# odometer               0.000
# registration_month     0.000
# fuel_type              8.964
# brand                  0.000
# unrepaired_damage     19.658
# ad_created             0.000
# nr_of_pictures         0.000
# postal_code            0.000
# last_seen              0.000
# dtype: float64

# %% [markdown]
# Our dataset is fairly complete, missing no more than 20% of values in any feature.
#
# Only 5 features have missing entries:
# * vehicle type (10.1% missing)
# * gearbox (5.3% missing)
# * model (5.5% missing)
# * fuel type (9.0% missing)
# * whether damage was repaired (19.7%)

# %% [markdown]
# ### Data Integrity
# Next, we use basic descriptive statistics to check data integrity.

# %%
# Descriptive statistics for numeric data
autos.describe()
# Out:
#        registration_year       powerps  registration_month  nr_of_pictures  \
# count       50000.000000  50000.000000        50000.000000         50000.0
# mean         2005.073280    116.355920            5.723360             0.0
# std           105.712813    209.216627            3.711984             0.0
# min          1000.000000      0.000000            0.000000             0.0
# 25%          1999.000000     70.000000            3.000000             0.0
# 50%          2003.000000    105.000000            6.000000             0.0
# 75%          2008.000000    150.000000            9.000000             0.0
# max          9999.000000  17700.000000           12.000000             0.0
#
#         postal_code
# count  50000.000000
# mean   50813.627300
# std    25779.747957
# min     1067.000000
# 25%    30451.000000
# 50%    49577.000000
# 75%    71540.000000
# max    99998.000000

# %%
# Descriptive statistics for string data
autos.describe(include=['O'])
# Out:
#                date_crawled         name  seller offer_type  price abtest  \
# count                 50000        50000   50000      50000  50000  50000
# unique                48213        38754       2          2   2357      2
# top     2016-03-08 10:40:35  Ford_Fiesta  privat    Angebot     $0   test
# freq                      3           78   49999      49999   1421  25756
#
#        vehicle_type  gearbox  model   odometer fuel_type       brand  \
# count         44905    47320  47242      50000     45518       50000
# unique            8        2    245         13         7          40
# top       limousine  manuell   golf  150,000km    benzin  volkswagen
# freq          12859    36993   4024      32424     30107       10687
#
#        unrepaired_damage           ad_created            last_seen
# count              40171                50000                50000
# unique                 2                   76                39481
# top                 nein  2016-04-03 00:00:00  2016-04-07 06:17:27
# freq               35232                 1946                    8

# %% [markdown]
# Observations:
# * `nr_of_pictures`, `seller`, and `offer_type` are monovalued, and so contribute no information
# * `registration_year` has a maximum of `9999`, which is likely a code for missingness
# * `registration_month` has a minimum of `0`, which is likely a code for missingness
# * `powerps` measures PS, where 1 PS $\approx$ 0.986 HP. A max PS of `17700` likely signals bad data entries
# * `price` has \$0 as its mode; it's unlikely that cars were given away for free, so a $0 perhaps means an expired posting
#
# We'll investigate registration dates, the listed PS, and the price further.

# %%
# Highest plausible date is 2019
autos["registration_year"].sort_values(ascending=False).head(20)
# Out:
# 38076    9999
# 33950    9999
# 14341    9999
# 8012     9999
# 6308     9996
# 13559    9000
# 49910    9000
# 25003    8888
# 8360     6200
# 27618    5911
# 24519    5000
# 49153    5000
# 4164     5000
# 22799    5000
# 42079    4800
# 453      4500
# 4549     4100
# 27578    2800
# 49185    2019
# 5763     2019
# Name: registration_year, dtype: int64

# %%
# Cars were invented in 1885, so lowest plausible date is 1910.
autos["registration_year"].sort_values().head(20)
# Out:
# 22316    1000
# 49283    1001
# 24511    1111
# 35238    1500
# 10556    1800
# 32585    1800
# 28693    1910
# 42181    1910
# 15898    1910
# 3679     1910
# 30781    1910
# 33295    1910
# 45157    1910
# 22659    1910
# 46213    1910
# 21416    1927
# 22101    1929
# 11246    1931
# 2573     1934
# 2221     1934
# Name: registration_year, dtype: int64

# %%
# 5075 records with registration month 0
autos[autos["registration_month"] == 0].shape[0]
# Out:
# 5075

# %%
# 54 rows with 1000 or more PS, which is greatly inflated.
# If a model is to be run using PS, these values should probably be 
# manually inspected, or thrown out with little data loss 
autos[autos["powerps"] >= 1000]
# Out:
#               date_crawled                                               name  \
# 1699   2016-04-04 19:49:19                        Opel_Corsa_1.0_Motor_ecotek
# 2220   2016-03-30 17:56:27                                Ford_ka_top_zustand
# 2670   2016-04-02 15:47:00                              Verkaufe_Ford_Focus_!
# 3753   2016-04-03 18:47:14                                         VW_Polo_9n
# 4405   2016-03-21 19:53:24                             VW_Golf_Automatik_Grau
# 4464   2016-03-29 16:47:47            Zu_verkaufen_Mercedes_A_160_mit_neu_TÜV
# 4777   2016-04-03 12:45:25              Audi_tt_bj_2000_Unfall.._laeuft_top..
# 8000   2016-03-16 00:18:43                                        Opel_zafira
# 9968   2016-03-14 15:50:17  Start_Stop_Leder_Lenkrad_mit_neuen_Alweterrreifen
# 10556  2016-04-01 06:02:10                                         UNFAL_Auto
# 10659  2016-03-18 11:47:40                            VW_POLO_BASTLERFAHRZEUG
# 10813  2016-03-12 09:58:22        Volkswagen_Kaefer_1303_1972_von_2e_eigenere
# 11009  2016-03-15 21:55:11               Smart_fortwo_Silver_**Brabus_Style**
# 11311  2016-04-01 02:36:43         Vw__zu__verkaufen__Caravelle_Confort_kurz_
# 11914  2016-03-09 22:56:46                 Volkswagen_Caravelle_VW_T4_2_5_TDI
# 13573  2016-03-12 10:56:09         A_140__Bastler_fahrzeug__mit_TÜV_bis_08/17
# 13903  2016-03-21 20:54:53                                     Gebrauchtwagen
# 14608  2016-03-29 20:38:00                            Seat_Ibiza_fuer_Bastler
# 16743  2016-03-17 23:53:06                                       Opel_Astra_j
# 17930  2016-03-05 14:49:03                             Opel_Astra_1.6_Caravan
# 17990  2016-03-28 10:51:46                                       206cc_caprio
# 18720  2016-03-24 11:50:41                Bmw_530d_tuev_euro_4_top_gepflegt_!
# 19352  2016-03-09 23:30:31                                        BMW_compact
# 19659  2016-03-28 19:53:13                                 Renault_zu_Verkauf
# 20421  2016-03-20 22:55:15                     Volvo_v40_Diesel__silber_Kombi
# 22592  2016-04-04 14:59:24                          Top_geopflegter_fiesta_st
# 23660  2016-03-20 17:54:04                                    BMW_535_touring
# 23742  2016-04-01 18:48:19                Gilf_3_rolling_stone_tuev_bis_11/17
# 24197  2016-04-02 11:48:54                                        Honda_Civic
# 24943  2016-03-30 09:53:11                                 Renault_Kangoo_1_2
# 25381  2016-03-16 16:44:25  Mercedes_C_Klasse_Kombi_Kompressor_Bj._2003__1...
# 27179  2016-04-06 05:36:24  ._Verkaufen.SEAT_TOLEDO_2.0l_diesel.mit_Tuv_05...
# 27580  2016-03-22 20:52:00                                     Toyota_Corolla
# 28399  2016-03-29 09:36:56              Fahrzeug_zum_Basteln_oder_Verwerten!!
# 29518  2016-03-28 12:47:52                                        opel_vectra
# 32585  2016-04-02 16:56:39                                         UNFAL_Auto
# 32805  2016-03-21 13:45:41                 W_lupo_um_sonderprais_zum_werkafen
# 33330  2016-03-12 16:46:14      Peugeot_307_2.0__HDI_136_Ps_xenonscheinwerfer
# 35039  2016-03-10 08:57:25                               Top_Cabrio_A4_s_line
# 36191  2016-03-25 14:55:04                            1.HAND__wenig_Kilometer
# 36421  2016-03-20 16:51:48                           Verkaufe_meinen_bmw_525d
# 36973  2016-03-14 13:58:16   Mercedes_E_Klasse_280_CDI_sehr_gepflegt_67500_km
# 37651  2016-03-29 19:44:48                           verkauf__bastler__export
# 40017  2016-03-05 17:48:02                              Ford_Focus_1.8_Diesel
# 40091  2016-03-14 13:58:10                                         Ford_Focus
# 40625  2016-03-24 11:51:57                  VW_TOURAN_HIGHLINE_2.0_TDI_DIESEL
# 41172  2016-04-03 14:45:36                      Suzuki_Baleno_1_3l_GS_TÜV_neu
# 41673  2016-04-02 11:51:51                                Opel_Agila_Silber_?
# 43870  2016-03-08 03:02:24  VW_Passat_2_0_TDi_Inzahlungn._/Tausche_gegen_T...
# 45465  2016-03-26 19:46:06                                Mercedes_Benz_e_270
# 45671  2016-03-18 00:51:03  PT_Cruiser_Crd_2.0_fuer_Kurzentschlossene_bis_...
# 46986  2016-03-22 22:55:30                            Skoda_Octavia_Combi_Tsi
# 47948  2016-03-20 17:40:16  Opel_Astra_J_Sports_Tourer_1_4Turbo_60700Km_Na...
# 49263  2016-04-02 15:55:11                             VW_Passat_1.9TDI_Kombi
#
#        seller offer_type    price   abtest vehicle_type  registration_year  \
# 1699   privat    Angebot   $1,200     test    limousine               2001
# 2220   privat    Angebot     $850  control          NaN               2005
# 2670   privat    Angebot     $360  control   kleinwagen               1999
# 3753   privat    Angebot   $4,700  control   kleinwagen               2009
# 4405   privat    Angebot   $2,200     test    limousine               1998
# 4464   privat    Angebot   $1,650  control   kleinwagen               2000
# 4777   privat    Angebot   $2,200  control        coupe               2000
# 8000   privat    Angebot   $2,599     test          NaN               2016
# 9968   privat    Angebot   $7,200  control   kleinwagen               2010
# 10556  privat    Angebot     $450  control          NaN               1800
# 10659  privat    Angebot     $100  control   kleinwagen               1996
# 10813  privat    Angebot   $3,950  control   kleinwagen               1972
# 11009  privat    Angebot   $2,550  control   kleinwagen               2004
# 11311  privat    Angebot   $8,600  control       andere               2007
# 11914  privat    Angebot   $3,200     test          NaN               2017
# 13573  privat    Angebot     $750  control   kleinwagen               1999
# 13903  privat    Angebot   $5,500  control    limousine               2007
# 14608  privat    Angebot   $1,000     test   kleinwagen               1996
# 16743  privat    Angebot   $9,799  control    limousine               2011
# 17930  privat    Angebot   $5,000  control        kombi               2007
# 17990  privat    Angebot   $2,798  control       cabrio               2005
# 18720  privat    Angebot   $7,498     test          NaN               2017
# 19352  privat    Angebot     $399  control       andere               1994
# 19659  privat    Angebot   $1,600  control          bus               2005
# 20421  privat    Angebot   $1,199     test        kombi               2000
# 22592  privat    Angebot   $5,200     test   kleinwagen               2005
# 23660  privat    Angebot   $9,750     test        kombi               2005
# 23742  privat    Angebot   $1,250  control          NaN               2017
# 24197  privat    Angebot   $1,500     test   kleinwagen               2000
# 24943  privat    Angebot   $1,150  control          bus               2001
# 25381  privat    Angebot   $3,990  control        kombi               2003
# 27179  privat    Angebot   $4,550  control          NaN               2017
# 27580  privat    Angebot   $3,200  control   kleinwagen               2004
# 28399  privat    Angebot     $800     test        kombi               2002
# 29518  privat    Angebot   $1,450     test    limousine               2000
# 32585  privat    Angebot     $450  control          NaN               1800
# 32805  privat    Angebot     $990     test        coupe               1999
# 33330  privat    Angebot   $3,500  control    limousine               2005
# 35039  privat    Angebot  $11,950     test       cabrio               2008
# 36191  privat    Angebot   $1,499  control    limousine               1998
# 36421  privat    Angebot   $6,000     test        kombi               2004
# 36973  privat    Angebot   $9,500     test    limousine               2004
# 37651  privat    Angebot     $500  control        kombi               1999
# 40017  privat    Angebot   $1,500     test        kombi               2003
# 40091  privat    Angebot     $600     test        kombi               2000
# 40625  privat    Angebot   $9,900     test          bus               2011
# 41172  privat    Angebot     $950     test   kleinwagen               2001
# 41673  privat    Angebot   $1,900     test   kleinwagen               2001
# 43870  privat    Angebot   $5,400  control        kombi               2006
# 45465  privat    Angebot   $2,200  control    limousine               2002
# 45671  privat    Angebot       $0     test          NaN               2016
# 46986  privat    Angebot   $5,000  control          NaN               2018
# 47948  privat    Angebot  $11,000     test        kombi               2010
# 49263  privat    Angebot   $1,250  control        kombi               2003
#
#          gearbox  powerps        model   odometer  registration_month  \
# 1699     manuell     6512        corsa  150,000km                  12
# 2220     manuell     1003           ka    5,000km                  12
# 2670         NaN     1988        focus  150,000km                   2
# 3753     manuell     6045         polo  125,000km                  12
# 4405   automatik     1781         golf  150,000km                  10
# 4464   automatik     1001     a_klasse  150,000km                   3
# 4777     manuell     1793           tt  150,000km                   4
# 8000     manuell     1779       zafira  150,000km                   0
# 9968     manuell     1016        yaris   30,000km                   4
# 10556        NaN     1800          NaN    5,000km                   2
# 10659    manuell     3750         polo  125,000km                   4
# 10813    manuell     1300       kaefer  150,000km                   0
# 11009  automatik     6226       fortwo  125,000km                   5
# 11311  automatik     3500  transporter  150,000km                  12
# 11914    manuell     1998  transporter  150,000km                   0
# 13573    manuell     1400     a_klasse  150,000km                   2
# 13903    manuell     1090        focus  150,000km                   3
# 14608    manuell     4400        ibiza   90,000km                   9
# 16743    manuell    14009          NaN   80,000km                   6
# 17930    manuell     1055        astra  125,000km                   8
# 17990        NaN     1082      2_reihe  150,000km                   6
# 18720  automatik     2018          5er  150,000km                   9
# 19352        NaN     1103          3er  150,000km                   0
# 19659    manuell     1202       scenic    5,000km                   5
# 20421    manuell     1056          v40  150,000km                   0
# 22592    manuell    15001       fiesta  150,000km                  12
# 23660  automatik     2729          5er  150,000km                   7
# 23742    manuell     9011         golf   60,000km                   5
# 24197    manuell     1400          NaN  150,000km                   0
# 24943    manuell     7511       kangoo  150,000km                  11
# 25381    manuell     1796     c_klasse  150,000km                  12
# 27179    manuell     1986       toledo  150,000km                   4
# 27580    manuell     1398      corolla    5,000km                   6
# 28399    manuell     1780     berlingo  150,000km                   6
# 29518  automatik     1800       vectra    5,000km                  12
# 32585        NaN     1800          NaN    5,000km                   2
# 32805    manuell     1000         lupo   20,000km                   5
# 33330    manuell     1367      3_reihe  150,000km                  11
# 35039    manuell    16312           a4   20,000km                   4
# 36191    manuell     1011          NaN  100,000km                  12
# 36421  automatik    17700          5er  150,000km                   7
# 36973  automatik     1771     e_klasse   70,000km                   9
# 37651    manuell     1001        astra  150,000km                   7
# 40017    manuell     1001        focus  150,000km                  10
# 40091    manuell     1753        focus  150,000km                  12
# 40625    manuell     1400       touran  150,000km                   1
# 41172    manuell     8404       andere  125,000km                   7
# 41673    manuell     5867        agila   70,000km                   6
# 43870    manuell     1405       passat  150,000km                   1
# 45465  automatik     1704     e_klasse  150,000km                   1
# 45671    manuell    15016    ptcruiser  150,000km                  12
# 46986    manuell    16011      octavia  150,000km                   2
# 47948    manuell     1401          NaN   70,000km                  11
# 49263  automatik     1998       passat    5,000km                  12
#
#       fuel_type          brand unrepaired_damage           ad_created  \
# 1699     benzin           opel               NaN  2016-04-04 00:00:00
# 2220     benzin           ford              nein  2016-03-30 00:00:00
# 2670     benzin           ford               NaN  2016-04-02 00:00:00
# 3753     benzin     volkswagen              nein  2016-04-03 00:00:00
# 4405     benzin     volkswagen                ja  2016-03-21 00:00:00
# 4464     benzin  mercedes_benz              nein  2016-03-29 00:00:00
# 4777        NaN           audi                ja  2016-04-03 00:00:00
# 8000     benzin           opel              nein  2016-03-14 00:00:00
# 9968     benzin         toyota               NaN  2016-03-14 00:00:00
# 10556       NaN     mitsubishi              nein  2016-04-01 00:00:00
# 10659    benzin     volkswagen                ja  2016-03-18 00:00:00
# 10813    benzin     volkswagen               NaN  2016-03-12 00:00:00
# 11009    benzin          smart              nein  2016-03-15 00:00:00
# 11311       NaN     volkswagen               NaN  2016-04-01 00:00:00
# 11914    diesel     volkswagen               NaN  2016-03-09 00:00:00
# 13573    benzin  mercedes_benz               NaN  2016-03-12 00:00:00
# 13903       NaN           ford              nein  2016-03-21 00:00:00
# 14608    benzin           seat                ja  2016-03-29 00:00:00
# 16743    benzin           opel              nein  2016-03-17 00:00:00
# 17930    benzin           opel              nein  2016-03-05 00:00:00
# 17990    benzin        peugeot               NaN  2016-03-28 00:00:00
# 18720       NaN            bmw              nein  2016-03-24 00:00:00
# 19352       NaN            bmw               NaN  2016-03-09 00:00:00
# 19659    diesel        renault               NaN  2016-03-28 00:00:00
# 20421       NaN          volvo              nein  2016-03-20 00:00:00
# 22592    benzin           ford              nein  2016-04-04 00:00:00
# 23660    diesel            bmw              nein  2016-03-20 00:00:00
# 23742       NaN     volkswagen              nein  2016-04-01 00:00:00
# 24197    benzin          honda               NaN  2016-04-02 00:00:00
# 24943    benzin        renault              nein  2016-03-30 00:00:00
# 25381    benzin  mercedes_benz              nein  2016-03-16 00:00:00
# 27179    diesel           seat               NaN  2016-04-06 00:00:00
# 27580    benzin         toyota              nein  2016-03-22 00:00:00
# 28399    benzin        citroen              nein  2016-03-29 00:00:00
# 29518    benzin           opel              nein  2016-03-28 00:00:00
# 32585       NaN     mitsubishi              nein  2016-04-02 00:00:00
# 32805    benzin     volkswagen               NaN  2016-03-21 00:00:00
# 33330    diesel        peugeot               NaN  2016-03-12 00:00:00
# 35039    benzin           audi              nein  2016-03-10 00:00:00
# 36191    benzin           opel               NaN  2016-03-25 00:00:00
# 36421    diesel            bmw              nein  2016-03-20 00:00:00
# 36973    diesel  mercedes_benz               NaN  2016-03-14 00:00:00
# 37651    benzin           opel               NaN  2016-03-29 00:00:00
# 40017    diesel           ford               NaN  2016-03-05 00:00:00
# 40091    diesel           ford              nein  2016-03-14 00:00:00
# 40625       NaN     volkswagen              nein  2016-03-24 00:00:00
# 41172    benzin         suzuki               NaN  2016-04-03 00:00:00
# 41673    benzin           opel              nein  2016-04-02 00:00:00
# 43870    diesel     volkswagen              nein  2016-03-08 00:00:00
# 45465       NaN  mercedes_benz                ja  2016-03-26 00:00:00
# 45671    diesel       chrysler               NaN  2016-03-17 00:00:00
# 46986    benzin          skoda                ja  2016-03-22 00:00:00
# 47948    benzin           opel               NaN  2016-03-20 00:00:00
# 49263    diesel     volkswagen              nein  2016-04-02 00:00:00
#
#        nr_of_pictures  postal_code            last_seen
# 1699                0        47198  2016-04-06 22:16:46
# 2220                0        45891  2016-04-05 06:17:55
# 2670                0        54459  2016-04-06 14:44:28
# 3753                0        48565  2016-04-05 19:17:39
# 4405                0        47198  2016-04-06 22:46:46
# 4464                0        89134  2016-04-04 01:18:34
# 4777                0        16248  2016-04-07 14:57:35
# 8000                0        60326  2016-04-06 18:45:49
# 9968                0        24107  2016-03-26 09:17:34
# 10556               0        63322  2016-04-01 09:42:30
# 10659               0        12489  2016-04-03 21:17:20
# 10813               0        26899  2016-03-23 20:46:39
# 11009               0        12359  2016-04-07 07:45:21
# 11311               0        30855  2016-04-07 05:17:11
# 11914               0        45892  2016-03-12 20:16:45
# 13573               0        24109  2016-03-13 01:46:51
# 13903               0        94160  2016-04-07 01:17:22
# 14608               0        32760  2016-04-04 05:55:48
# 16743               0        86415  2016-03-23 17:18:38
# 17930               0        26388  2016-03-17 21:16:38
# 17990               0        66978  2016-03-30 01:15:42
# 18720               0        59425  2016-03-30 12:46:26
# 19352               0        56235  2016-03-16 23:15:31
# 19659               0        49086  2016-04-04 23:44:58
# 20421               0        34576  2016-04-07 11:17:03
# 22592               0        70372  2016-04-06 16:17:54
# 23660               0        21376  2016-03-23 02:48:53
# 23742               0        34121  2016-04-01 18:48:19
# 24197               0        21509  2016-04-04 09:15:26
# 24943               0        53757  2016-04-07 00:17:44
# 25381               0         8428  2016-03-27 21:17:44
# 27179               0        78739  2016-04-06 05:36:24
# 27580               0        22043  2016-03-22 21:43:26
# 28399               0        47228  2016-03-31 09:55:12
# 29518               0         6112  2016-04-06 15:46:31
# 32585               0        63322  2016-04-04 14:46:21
# 32805               0        88515  2016-04-06 09:15:48
# 33330               0        45144  2016-03-12 16:46:14
# 35039               0        51647  2016-03-17 09:16:19
# 36191               0        47475  2016-04-06 18:18:38
# 36421               0        26316  2016-04-06 22:45:56
# 36973               0        50859  2016-03-31 00:45:52
# 37651               0        33154  2016-04-06 05:44:36
# 40017               0        32791  2016-03-12 05:18:00
# 40091               0        49847  2016-03-23 14:46:49
# 40625               0        67067  2016-04-01 06:18:26
# 41172               0         1594  2016-04-05 13:45:11
# 41673               0        46147  2016-04-06 09:46:07
# 43870               0         3238  2016-03-16 07:45:56
# 45465               0        31812  2016-04-06 09:44:59
# 45671               0        24802  2016-03-20 09:51:49
# 46986               0        12681  2016-03-23 07:41:08
# 47948               0        10315  2016-04-01 02:47:29
# 49263               0        33719  2016-04-06 14:46:09

# %% [markdown]
# Further observations:
# * There are a number of rows with registration years way above `2019`, the year this script was created; these years should be coded as missing
# * `5075` rows have `0` as the registration month; a possible imputation could use `1` for January and instead rely on the year if registration date is important
# * `54` rows have `1000` or more PS for cars that obviously don't have that PS; this means that PS is fairly clean, but any modeling effort will need to drop or otherwise correct these values
#
# To continue, the `price` and `odometer` columns should be converted to numeric types.

# %%
# Check for non-numeric strings
autos["price"].str.replace('[0-9|,]+','').unique() # all rows begin with $
autos["odometer"].str.replace('[0-9|,]+','').unique() # all rows end in km

# Convert price and odometer to float types
autos["price"] = autos["price"].str.replace('[^0-9]','').astype(float)
autos["odometer"] = autos["odometer"].str.replace('[^0-9]','').astype(float)

# Rename odometer to odometer_km to include units in name
autos = autos.rename({"odometer" : "odometer_km"}, axis=1)

# %%
# Descriptive statistics of price and odometer_km, formatted to 2 decimals
autos[["price", "odometer_km"]].describe().applymap(lambda x: format(x, '.2f'))
# Out:
#              price odometer_km
# count     50000.00    50000.00
# mean       9840.04   125732.70
# std      481104.38    40042.21
# min           0.00     5000.00
# 25%        1100.00   125000.00
# 50%        2950.00   150000.00
# 75%        7200.00   150000.00
# max    99999999.00   150000.00

# %%
# Except for the Ferrari F40 (id: 7814) and Ferrari FXX (id: 47634),
# all other prices look obviously typed in to mean missing
autos.sort_values("price", ascending=False).head(20)
# Out:
#               date_crawled                                               name  \
# 39705  2016-03-22 14:58:27                        Tausch_gegen_gleichwertiges
# 42221  2016-03-08 20:39:05                                  Leasinguebernahme
# 27371  2016-03-09 15:45:47                                         Fiat_Punto
# 39377  2016-03-08 23:53:51                        Tausche_volvo_v40_gegen_van
# 47598  2016-03-31 18:56:54  Opel_Vectra_B_1_6i_16V_Facelift_Tuning_Showcar...
# 2897   2016-03-12 21:50:57   Escort_MK_1_Hundeknochen_zum_umbauen_auf_RS_2000
# 24384  2016-03-21 13:57:51                            Schlachte_Golf_3_gt_tdi
# 11137  2016-03-29 23:52:57  suche_maserati_3200_gt_Zustand_unwichtig_laufe...
# 47634  2016-04-04 21:25:21                                        Ferrari_FXX
# 7814   2016-04-04 11:53:31                                        Ferrari_F40
# 22947  2016-03-22 12:54:19                         Bmw_530d_zum_ausschlachten
# 43049  2016-03-21 19:53:52                                      2_VW_Busse_T3
# 514    2016-03-17 09:53:08                   Ford_Focus_Turnier_1.6_16V_Style
# 37585  2016-03-29 11:38:54                                Volkswagen_Jetta_GT
# 36818  2016-03-27 18:37:37                                        Porsche_991
# 14715  2016-03-30 08:37:24                 Rolls_Royce_Phantom_Drophead_Coupe
# 34723  2016-03-23 16:37:29  Porsche_Porsche_911/930_Turbo_3.0__deutsche_Au...
# 35923  2016-04-03 07:56:23  Porsche_911_Targa_Exclusive_Edition__1_von_15_...
# 12682  2016-03-28 22:48:01  Porsche_GT3_RS__PCCB__Lift___grosser_Exklusiv_...
# 47337  2016-04-05 10:25:38                                    BMW_Z8_roadster
#
#        seller offer_type       price   abtest vehicle_type  registration_year  \
# 39705  privat    Angebot  99999999.0  control    limousine               1999
# 42221  privat    Angebot  27322222.0  control    limousine               2014
# 27371  privat    Angebot  12345678.0  control          NaN               2017
# 39377  privat    Angebot  12345678.0  control          NaN               2018
# 47598  privat    Angebot  12345678.0  control    limousine               2001
# 2897   privat    Angebot  11111111.0     test    limousine               1973
# 24384  privat    Angebot  11111111.0     test          NaN               1995
# 11137  privat    Angebot  10000000.0  control        coupe               1960
# 47634  privat    Angebot   3890000.0     test        coupe               2006
# 7814   privat    Angebot   1300000.0  control        coupe               1992
# 22947  privat    Angebot   1234566.0  control        kombi               1999
# 43049  privat    Angebot    999999.0     test          bus               1981
# 514    privat    Angebot    999999.0     test        kombi               2009
# 37585  privat    Angebot    999990.0     test    limousine               1985
# 36818  privat    Angebot    350000.0  control        coupe               2016
# 14715  privat    Angebot    345000.0  control       cabrio               2012
# 34723  privat    Angebot    299000.0     test        coupe               1977
# 35923  privat    Angebot    295000.0     test       cabrio               2015
# 12682  privat    Angebot    265000.0  control        coupe               2016
# 47337  privat    Angebot    259000.0     test       cabrio               2001
#
#          gearbox  powerps        model  odometer_km  registration_month  \
# 39705  automatik      224     s_klasse     150000.0                   9
# 42221    manuell      163           c4      40000.0                   2
# 27371        NaN       95        punto     150000.0                   0
# 39377    manuell       95          v40     150000.0                   6
# 47598    manuell      101       vectra     150000.0                   3
# 2897     manuell       48       escort      50000.0                   3
# 24384        NaN        0          NaN     150000.0                   0
# 11137    manuell      368          NaN     100000.0                   1
# 47634        NaN      799          NaN       5000.0                   7
# 7814         NaN        0          NaN      50000.0                  12
# 22947  automatik      190          NaN     150000.0                   2
# 43049    manuell       70  transporter     150000.0                   1
# 514      manuell      101        focus     125000.0                   4
# 37585    manuell      111        jetta     150000.0                  12
# 36818    manuell      500          911       5000.0                   3
# 14715  automatik      460          NaN      20000.0                   8
# 34723    manuell      260          911     100000.0                   7
# 35923  automatik      400          911       5000.0                   6
# 12682  automatik      500          911       5000.0                   3
# 47337    manuell      400      z_reihe      20000.0                   6
#
#       fuel_type           brand unrepaired_damage           ad_created  \
# 39705    benzin   mercedes_benz               NaN  2016-03-22 00:00:00
# 42221    diesel         citroen               NaN  2016-03-08 00:00:00
# 27371       NaN            fiat               NaN  2016-03-09 00:00:00
# 39377       NaN           volvo              nein  2016-03-08 00:00:00
# 47598    benzin            opel              nein  2016-03-31 00:00:00
# 2897     benzin            ford              nein  2016-03-12 00:00:00
# 24384       NaN      volkswagen               NaN  2016-03-21 00:00:00
# 11137    benzin  sonstige_autos              nein  2016-03-29 00:00:00
# 47634       NaN  sonstige_autos              nein  2016-04-04 00:00:00
# 7814        NaN  sonstige_autos              nein  2016-04-04 00:00:00
# 22947    diesel             bmw               NaN  2016-03-22 00:00:00
# 43049    benzin      volkswagen               NaN  2016-03-21 00:00:00
# 514      benzin            ford              nein  2016-03-17 00:00:00
# 37585    benzin      volkswagen                ja  2016-03-29 00:00:00
# 36818    benzin         porsche              nein  2016-03-27 00:00:00
# 14715    benzin  sonstige_autos              nein  2016-03-30 00:00:00
# 34723    benzin         porsche              nein  2016-03-23 00:00:00
# 35923    benzin         porsche              nein  2016-04-03 00:00:00
# 12682    benzin         porsche              nein  2016-03-28 00:00:00
# 47337    benzin             bmw              nein  2016-04-05 00:00:00
#
#        nr_of_pictures  postal_code            last_seen
# 39705               0        73525  2016-04-06 05:15:30
# 42221               0        76532  2016-03-08 20:39:05
# 27371               0        96110  2016-03-09 15:45:47
# 39377               0        14542  2016-04-06 23:17:31
# 47598               0         4356  2016-03-31 18:56:54
# 2897                0        94469  2016-03-12 22:45:27
# 24384               0        18519  2016-03-21 14:40:18
# 11137               0        73033  2016-04-06 21:18:11
# 47634               0        60313  2016-04-05 12:07:37
# 7814                0        60598  2016-04-05 11:34:11
# 22947               0        17454  2016-04-02 03:17:32
# 43049               0        99880  2016-03-28 17:18:28
# 514                 0        12205  2016-04-06 07:17:35
# 37585               0        50997  2016-03-29 11:38:54
# 36818               0        70499  2016-03-27 18:37:37
# 14715               0        73525  2016-04-07 00:16:26
# 34723               0        61462  2016-04-06 16:44:50
# 35923               0        74078  2016-04-03 08:56:20
# 12682               0        70193  2016-04-05 03:44:51
# 47337               0        61462  2016-04-05 12:07:32

# %%
autos[autos["price"] == 0].shape[0] # 1421 rows with 0 price
# Out:
# 1421

# %% [markdown]
# More observations:
# * `1,421` rows have `0` price, which probably means the listing ended
# * `9` rows have an absurd price like `12345678`, which likely refer to missing values
# * `odometer` appears to be a reliable and clean column

# %% [markdown]
# ### Dealing with outliers and odd values

# %% [markdown]
# #### Prices
# Let's set any prices at or above 999,999 to Null, except for the Ferrari entries, since the cars with these values in the dataset are associated with common consumer vehicles and not exotic cars.

# %%
# Set to missing any non-Ferrari price greater or equal to 999999
autos.loc[(autos["price"] >= 999999) & ~(autos["name"].str.contains("Ferrari")), "price"] = np.nan

# %% [markdown]
# #### Registration Month and Year
# Let's set any registration months with a value of 0 to 1 to impute January as the earliest date possibly registered within the year. In addition, we'll truncate any dates before 1910 and after 2019.
#
# This will impute 5075 registration months, and truncate 24 bad registration years.

# %%
# Impute missing registration months, and set years above 2019 to NaN
autos.loc[autos["registration_month"] == 0, "registration_month"] = 1
autos.loc[(autos["registration_year"] > 2019) | 
          (autos["registration_year"] < 1910), "registration_year"] = np.nan

# %% [markdown]
# ### Processing Date Columns
# Unlike `registration_month` and `registration_year`, `date_crawled`, `last_seen`, and `ad_created` are datestamps that are not automatically converted by `pandas`, so we'll need to manually convert these to YYYY-MM-DD to do further analysis.

# %%
def describe_date(datestamp_col):
    return(
        (datestamp_col
            .str[:10] # First 10 characters is YYYY-MM-DD
            .value_counts(normalize=True, dropna=False) # summarize distribution
            .sort_index()
        ) # sort by earliest to latest date
    )

# %%
describe_date(autos["date_crawled"])
# Out:
# 2016-03-05    0.02538
# 2016-03-06    0.01394
# 2016-03-07    0.03596
# 2016-03-08    0.03330
# 2016-03-09    0.03322
# 2016-03-10    0.03212
# 2016-03-11    0.03248
# 2016-03-12    0.03678
# 2016-03-13    0.01556
# 2016-03-14    0.03662
# 2016-03-15    0.03398
# 2016-03-16    0.02950
# 2016-03-17    0.03152
# 2016-03-18    0.01306
# 2016-03-19    0.03490
# 2016-03-20    0.03782
# 2016-03-21    0.03752
# 2016-03-22    0.03294
# 2016-03-23    0.03238
# 2016-03-24    0.02910
# 2016-03-25    0.03174
# 2016-03-26    0.03248
# 2016-03-27    0.03104
# 2016-03-28    0.03484
# 2016-03-29    0.03418
# 2016-03-30    0.03362
# 2016-03-31    0.03192
# 2016-04-01    0.03380
# 2016-04-02    0.03540
# 2016-04-03    0.03868
# 2016-04-04    0.03652
# 2016-04-05    0.01310
# 2016-04-06    0.00318
# 2016-04-07    0.00142
# Name: date_crawled, dtype: float64

# %%
describe_date(autos["ad_created"])
# Out:
# 2015-06-11    0.00002
# 2015-08-10    0.00002
# 2015-09-09    0.00002
# 2015-11-10    0.00002
# 2015-12-05    0.00002
# 2015-12-30    0.00002
# 2016-01-03    0.00002
# 2016-01-07    0.00002
# 2016-01-10    0.00004
# 2016-01-13    0.00002
# 2016-01-14    0.00002
# 2016-01-16    0.00002
# 2016-01-22    0.00002
# 2016-01-27    0.00006
# 2016-01-29    0.00002
# 2016-02-01    0.00002
# 2016-02-02    0.00004
# 2016-02-05    0.00004
# 2016-02-07    0.00002
# 2016-02-08    0.00002
# 2016-02-09    0.00004
# 2016-02-11    0.00002
# 2016-02-12    0.00006
# 2016-02-14    0.00004
# 2016-02-16    0.00002
# 2016-02-17    0.00002
# 2016-02-18    0.00004
# 2016-02-19    0.00006
# 2016-02-20    0.00004
# 2016-02-21    0.00006
#                ...
# 2016-03-09    0.03324
# 2016-03-10    0.03186
# 2016-03-11    0.03278
# 2016-03-12    0.03662
# 2016-03-13    0.01692
# 2016-03-14    0.03522
# 2016-03-15    0.03374
# 2016-03-16    0.03000
# 2016-03-17    0.03120
# 2016-03-18    0.01372
# 2016-03-19    0.03384
# 2016-03-20    0.03786
# 2016-03-21    0.03772
# 2016-03-22    0.03280
# 2016-03-23    0.03218
# 2016-03-24    0.02908
# 2016-03-25    0.03188
# 2016-03-26    0.03256
# 2016-03-27    0.03090
# 2016-03-28    0.03496
# 2016-03-29    0.03414
# 2016-03-30    0.03344
# 2016-03-31    0.03192
# 2016-04-01    0.03380
# 2016-04-02    0.03508
# 2016-04-03    0.03892
# 2016-04-04    0.03688
# 2016-04-05    0.01184
# 2016-04-06    0.00326
# 2016-04-07    0.00128
# Name: ad_created, Length: 76, dtype: float64

# %%
describe_date(autos["last_seen"])
# Out:
# 2016-03-05    0.00108
# 2016-03-06    0.00442
# 2016-03-07    0.00536
# 2016-03-08    0.00760
# 2016-03-09    0.00986
# 2016-03-10    0.01076
# 2016-03-11    0.01252
# 2016-03-12    0.02382
# 2016-03-13    0.00898
# 2016-03-14    0.01280
# 2016-03-15    0.01588
# 2016-03-16    0.01644
# 2016-03-17    0.02792
# 2016-03-18    0.00742
# 2016-03-19    0.01574
# 2016-03-20    0.02070
# 2016-03-21    0.02074
# 2016-03-22    0.02158
# 2016-03-23    0.01858
# 2016-03-24    0.01956
# 2016-03-25    0.01920
# 2016-03-26    0.01696
# 2016-03-27    0.01602
# 2016-03-28    0.02086
# 2016-03-29    0.02234
# 2016-03-30    0.02484
# 2016-03-31    0.02384
# 2016-04-01    0.02310
# 2016-04-02    0.02490
# 2016-04-03    0.02536
# 2016-04-04    0.02462
# 2016-04-05    0.12428
# 2016-04-06    0.22100
# 2016-04-07    0.13092
# Name: last_seen, dtype: float64

# %%
autos["registration_year"].describe()
# Out:
# count    49976.000000
# mean      2003.366836
# std          7.693943
# min       1910.000000
# 25%       1999.000000
# 50%       2003.000000
# 75%       2008.000000
# max       2019.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# Observations:
# * For both `date_crawled` and `ad_created`, it appears that most listings appeared between March 7th and April 4th with about 3% of listings appearing every day between these dates almost uniformly
# * Some ads are quite old, going all the way back to 2015
# * Cars are more frequently last seen closer to the last date available, April 7th; in addition, almost half of all cars were last seen between April 5th and April 7th
#     * This last point is probably because the car was last seen at the same time the ad was crawled
# * Registration years ranged from 1910 to 2019, and it appears that the majority of registrations occured between 1999 and 2008, going by IQR

# %% [markdown]
# ## Data Aggregation

# %% [markdown]
# ### Average sales for the top 10 car brands

# %% [markdown]
# Let's see what the mean prices are for the top 10 most frequent car brands. Noting earlier that there are a number of \$0 prices that are probably implausible, we'll summarize the values by sales with nominal values above \$0.

# %%
# Find the mean price for the top 10 brands
top_10_brands = autos["brand"].value_counts().iloc[:10].index
mean_price_top_10 = {}

for b in top_10_brands:
    mean_price_top_10[b] = autos.loc[(autos["brand"] == b) &
                                     (autos["price"] != 0), "price"].mean()

# %%
# Sort the dictionary values using itemgetter
from operator import itemgetter
sorted(mean_price_top_10.items(), key=itemgetter(1), reverse=True)
# Out:
# [('audi', 9212.9306621881),
#  ('mercedes_benz', 8536.027085124677),
#  ('bmw', 8261.382442169132),
#  ('volkswagen', 5428.701460771984),
#  ('seat', 4315.744565217391),
#  ('ford', 3728.4121821407452),
#  ('peugeot', 3065.611888111888),
#  ('opel', 2944.6075421641085),
#  ('fiat', 2793.8700475435817),
#  ('renault', 2431.195698924731)]

# %% [markdown]
# Executive summary:
# * The top 10 brands were Audi, BMW, Fiat, Ford, Mercedes-Benz, Opel, Peugeot, Renault, SEAT, and Volkswagen
# * Audi had the highest used car price at \$9,212
# * Renault had the lowest used car price at \$2,431
# * Audi, Mercedes-Benz, and BMW had the three highest average sale prices
# * Opel, Fiat, and Renault had the three lowest average sale prices

# %% [markdown]
# ### Average mileage of top 6 brands sold

# %% [markdown]
# It would be interesting not just to see the top 10 mean prices, but also what kind of average mileage those cars sold had. To facilitate this, we'll present the mean price and mean milage together.

# %%
mean_miles_top_10 = {}

for b in top_10_brands:
    mean_miles_top_10[b] = autos.loc[(autos["brand"] == b) &
                                     (autos["price"] != 0), "odometer_km"].mean()

# %%
# pandas interprets keys of a list of dictionaries as columns, not as indexes
# so to properly code as columns in a line, we use the index argument and
# transpose the resulting matrix
(pd.DataFrame([pd.Series(mean_price_top_10), pd.Series(mean_miles_top_10)],
             index = ['mean_price', 'mean_mileage'])
   .T
   .applymap(lambda x: format(x, '.0f'))
)
# Out:
#               mean_price mean_mileage
# audi                9213       129493
# bmw                 8261       132686
# fiat                2794       117593
# ford                3728       124328
# mercedes_benz       8536       130801
# opel                2945       129387
# peugeot             3066       127357
# renault             2431       128062
# seat                4316       121641
# volkswagen          5429       128903

# %% [markdown]
# Executive summary:
# * All the top 10 car brands had mean mileages well above between 115,000 - 135,000
# * These brands sell even when mileage is very high, indicating some kind of consumer confidence

# %% [markdown]
# ## Extra Data Cleaning

# %% [markdown]
# ### Translating German words to English
# We can use `Series.replace()` to efficiently translate German words to English words for the categorical variables in the dataset.
#
# The workflow we'll use is to list the unique categories, and then replace any German words with English translations.

# %%
# Strings are stored as 'object' types in pandas
autos.describe(include='O')

# %% [markdown]
# `vehicle_type`, `gearbox`, `fuel_type`, and `unrepaired_damage` are informative columns that are worth translating for analytical convenience in English.

# %% [markdown]
# #### Vehicle Type

# %%
autos["vehicle_type"].unique() # Before translation

# %% [markdown]
# ##### Translation Notes:
# * [Kombi](https://en.wikipedia.org/wiki/Volkswagen_Type_2) refers to the Voltzwagen Type 2 vehicles. English translations are informal by nature, so I'll opt to keep this value as is
# * [Kleinwagen](https://en.wikipedia.org/wiki/Subcompact_car) translates to the American classification *subcompact*, and I use this translation to keep the category to one word

# %%
autos["vehicle_type"].replace({'kleinwagen' : 'subcompact',
                               'cabrio' : 'convertible',
                               'andere' : 'other'},
                              inplace = True)

# %%
autos["vehicle_type"].unique() # After translation

# %% [markdown]
# #### Gearbox

# %%
autos["gearbox"].unique() # Before translation

# %%
autos["gearbox"].replace({'manuell' : 'manual',
                          'automatik' : 'automatic'},
                         inplace = True)

# %%
autos["gearbox"].unique() # After translation

# %% [markdown]
# #### Fuel Type

# %%
autos["fuel_type"].unique() # Before translation

# %% [markdown]
# ##### Translation Notes
# * *Benzin* refers to the colloquial *gas* in English for petroleum gas, but to keep it simple, I just call it `gas` here
# * *LPG* and *CNG* are liquified petroleum gas and compressed natural gas, so these don't need to be translated

# %%
autos["fuel_type"].replace({'benzin' : 'gas',
                            'elektro' : 'electric',
                            'andere' : 'other'},
                           inplace = True)

# %%
autos["fuel_type"].unique() # After translation

# %% [markdown]
# ##### Unrepaired Damage

# %%
autos["unrepaired_damage"].unique() # Before translation

# %%
# map() is faster than replace(), and only 2 values to replace so
# I opted to use that
autos["unrepaired_damage"] = autos["unrepaired_damage"].map({'nein' : 'no', 'ja' : 'yes'})

# %%
autos["unrepaired_damage"].unique() # After translation

# %% [markdown]
# ## Extra Analysis

# %% [markdown]
# ### Most common brand and model combinations
# One interesting question to answer is: which models are the most common for each brand?
#
# We'll answer this in a table of all brands and the most popular model in each brand, along with the count of listings in the dataset.

# %%
# Idea: Find the largest count within each brand using grouping
max_brand_model = (autos
                     .groupby(["brand","model"])
                     .size()
                     .groupby(level=0, group_keys=False)
                     .nlargest(n=1)
                     .to_frame('size')
                     .rename({'size' : 'N'}, axis=1)
                  )

# %%
max_brand_model.style

# %% [markdown]
# We can also find out which three combinations of brand and model have the most listings.

# %%
max_brand_model.sort_values("N").tail(3)

# %% [markdown]
# Looks like the top three most common brand and model listings are:
# * Opel Corsa
# * BMW 3 Series
# * Volkswagen Golf
#
# Together, these three specific brand and models make up 8,520 of the listings, or 17% of the listings.

# %% [markdown]
# ### Average prices by mileage
# It appeared in our earlier analysis of the mileage of the top 10 brands by selling price that many cars with high mileage (115,000+) were being sold. It is possible that 1) high mileage results in lower sale value due to depreciation, and 2) the high mileage cars drag the overall average sale price down.
#
# We can explore this by looking at sales data by mileage to see if there is an overall effect.

# %%
(1735+2761+4024) / 50000
# Out:
# 0.1704

# %%
# Distribution of mileage
autos["odometer_km"].value_counts()
# Out:
# 150000.0    32424
# 125000.0     5170
# 100000.0     2169
# 90000.0      1757
# 80000.0      1436
# 70000.0      1230
# 60000.0      1164
# 50000.0      1027
# 5000.0        967
# 40000.0       819
# 30000.0       789
# 20000.0       784
# 10000.0       264
# Name: odometer_km, dtype: int64

# %% [markdown]
# As suspected, the dataset is mostly represented by cars with 150,000 km or more of mileage. Because of this, quartiles have little meaning here. To see this, let's get simple summary statistics.

# %%
autos["odometer_km"].describe()
# Out:
# count     50000.000000
# mean     125732.700000
# std       40042.211706
# min        5000.000000
# 25%      125000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: odometer_km, dtype: float64

# %% [markdown]
# As we can see from the summary statistics, the 25th percentile is already 125,000 km, and the median at 150,000 km, or the max of the dataset. Since there aren't too many mileage categories, let's find the average prices for each mileage category.

# %%
# Among all nonzero prices, find the mean price for each mileage label
(autos[autos["price"] != 0]
    .groupby("odometer_km")["price"]
    .mean()
    .round()
)
# Out:
# odometer_km
# 5000.0      13168.0
# 10000.0     20248.0
# 20000.0     18054.0
# 30000.0     16532.0
# 40000.0     15481.0
# 50000.0     14982.0
# 60000.0     12243.0
# 70000.0     10868.0
# 80000.0      9614.0
# 90000.0      8369.0
# 100000.0     8017.0
# 125000.0     6139.0
# 150000.0     3760.0
# Name: price, dtype: float64

# %% [markdown]
# Aha! Looks like mileage is inversely proportional to average price, meaning that depreciation in the dataset is very real. Cars with higher mileage tend to have lower sale prices.
#
# Interestingly, cars with less than 100,000 km sell on average for at least \$8,000, and prices for low mileage cars of 20,000 km or less sell for at least \$18,000 on average.

# %% [markdown]
# ### Average price of damaged cars vs non-damaged cars
# Similar to our analysis above, we can look at how much damaged cars sell for compared to non-damaged cars.

# %%
(autos[autos["price"] != 0]
     .groupby("unrepaired_damage")["price"]
     .mean()
     .round()
)
# Out:
# unrepaired_damage
# ja      2435.0
# nein    7236.0
# Name: price, dtype: float64

# %% [markdown]
# For this dataset, non-damaged cars (i.e. cars without unrepaired damage) sell for almost \$5,000 more compared to their damaged counterparts.
